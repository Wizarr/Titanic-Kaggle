# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import matplotlib.mlab as mlab

# %matplotlib inline

# %%
 pd.read_csv('C:/Users/Toshiba/Downloads/Titanic/train.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df1 =  pd.read_csv('C:/Users/Toshiba/Downloads/Titanic/train.csv')

# %% [markdown]
# #

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df1.columns
# Out:
# Index([u'PassengerId', u'Survived', u'Pclass', u'Name', u'Sex', u'Age',
#        u'SibSp', u'Parch', u'Ticket', u'Fare', u'Cabin', u'Embarked'],
#       dtype='object')

# %%
df1.values
# Out:
# array([[1L, 0L, 3L, ..., 7.25, nan, 'S'],
#        [2L, 1L, 1L, ..., 71.2833, 'C85', 'C'],
#        [3L, 1L, 3L, ..., 7.925, nan, 'S'],
#        ...,
#        [889L, 0L, 3L, ..., 23.45, nan, 'S'],
#        [890L, 1L, 1L, ..., 30.0, 'C148', 'C'],
#        [891L, 0L, 3L, ..., 7.75, nan, 'Q']], dtype=object)

# %%
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df1.T
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                               22
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                         38
# ...

# %%
df1.sort
# Out:
# <bound method DataFrame.sort of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df1.sort_index(axis=1, ascending=True)
# Out:
#       Age        Cabin Embarked      Fare  \
# 0    22.0          NaN        S    7.2500
# 1    38.0          C85        C   71.2833
# 2    26.0          NaN        S    7.9250
# 3    35.0         C123        S   53.1000
# 4    35.0          NaN        S    8.0500
# 5     NaN          NaN        Q    8.4583
# 6    54.0          E46        S   51.8625
# 7     2.0          NaN        S   21.0750
# 8    27.0          NaN        S   11.1333
# 9    14.0          NaN        C   30.0708
# 10    4.0           G6        S   16.7000
# 11   58.0         C103        S   26.5500
# 12   20.0          NaN        S    8.0500
# 13   39.0          NaN        S   31.2750
# 14   14.0          NaN        S    7.8542
# 15   55.0          NaN        S   16.0000
# 16    2.0          NaN        Q   29.1250
# 17    NaN          NaN        S   13.0000
# 18   31.0          NaN        S   18.0000
# 19    NaN          NaN        C    7.2250
# 20   35.0          NaN        S   26.0000
# ...

# %%
df1.sort_values(by='Cabin')
# Out:
#      PassengerId  Survived  Pclass  \
# 583          584         0       1
# 475          476         0       1
# 556          557         1       1
# 284          285         0       1
# 599          600         1       1
# 630          631         1       1
# 867          868         0       1
# 647          648         1       1
# 209          210         1       1
# 185          186         0       1
# 445          446         1       1
# 806          807         0       1
# 96            97         0       1
# 23            24         1       1
# 174          175         0       1
# 737          738         1       1
# 815          816         0       1
# 523          524         1       1
# 329          330         1       1
# 170          171         0       1
# 690          691         1       1
# 781          782         1       1
# 745          746         0       1
# 540          541         1       1
# 61            62         1       1
# ...

# %%
df1['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
# 5      Q
# 6      S
# 7      S
# 8      S
# 9      C
# 10     S
# 11     S
# 12     S
# 13     S
# 14     S
# 15     S
# 16     Q
# 17     S
# 18     S
# 19     C
# 20     S
# 21     S
# 22     Q
# 23     S
# 24     S
# 25     S
# 26     C
# 27     S
# 28     Q
# 29     S
#       ..
# 861    S
# 862    S
# 863    S
# 864    S
# 865    S
# 866    C
# 867    S
# 868    S
# 869    S
# 870    S
# 871    S
# 872    S
# 873    S
# 874    C
# 875    C
# 876    S
# 877    S
# 878    S
# 879    C
# 880    S
# 881    S
# 882    S
# 883    S
# 884    S
# 885    Q
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, dtype: object

# %%
df1.loc[:,['Cabin','Sex']]
# Out:
#            Cabin     Sex
# 0            NaN    male
# 1            C85  female
# 2            NaN  female
# 3           C123  female
# 4            NaN    male
# 5            NaN    male
# 6            E46    male
# 7            NaN    male
# 8            NaN  female
# 9            NaN  female
# 10            G6  female
# 11          C103  female
# 12           NaN    male
# 13           NaN    male
# 14           NaN  female
# 15           NaN  female
# 16           NaN    male
# 17           NaN    male
# 18           NaN  female
# 19           NaN  female
# 20           NaN    male
# 21           D56    male
# 22           NaN  female
# 23            A6    male
# 24           NaN  female
# 25           NaN  female
# 26           NaN    male
# 27   C23 C25 C27    male
# 28           NaN  female
# 29           NaN    male
# ..           ...     ...
# 861          NaN    male
# 862          D17  female
# 863          NaN  female
# 864          NaN    male
# 865          NaN  female
# ...

# %%
pd.isnull(df1)
# Out:
#     PassengerId Survived Pclass   Name    Sex    Age  SibSp  Parch Ticket  \
# 0         False    False  False  False  False  False  False  False  False
# 1         False    False  False  False  False  False  False  False  False
# 2         False    False  False  False  False  False  False  False  False
# 3         False    False  False  False  False  False  False  False  False
# 4         False    False  False  False  False  False  False  False  False
# 5         False    False  False  False  False   True  False  False  False
# 6         False    False  False  False  False  False  False  False  False
# 7         False    False  False  False  False  False  False  False  False
# 8         False    False  False  False  False  False  False  False  False
# 9         False    False  False  False  False  False  False  False  False
# 10        False    False  False  False  False  False  False  False  False
# 11        False    False  False  False  False  False  False  False  False
# ...

# %%
df1.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %% [markdown]
# df1.apply(np.cumsum)

# %%
df1.apply(np.cumsum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-99a7b442db9a> in <module>()
# ----> 1 df1.apply(np.cumsum)
#
# C:\Users\Toshiba\Anaconda3\lib\site-packages\pandas\core\frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4150                     if reduce is None:
#    4151                         reduce = True
# -> 4152                     return self._apply_standard(f, axis, reduce=reduce)
#    4153             else:
#    4154                 return self._apply_broadcast(f, axis)
#
# C:\Users\Toshiba\Anaconda3\lib\site-packages\pandas\core\frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4246             try:
#    4247                 for i, v in enumerate(series_gen):
# -> 4248                     results[i] = func(v)
#    4249                     keys.append(v.name)
# ...

# %%
 df1.groupby('Cabin').sum()
# Out:
#        PassengerId  Survived  Pclass    Age  SibSp  Parch      Fare
# Cabin
# A10            584         0       1   36.0      0      0   40.1250
# A14            476         0       1    NaN      0      0   52.0000
# A16            557         1       1   48.0      1      0   39.6000
# A19            285         0       1    NaN      0      0   26.0000
# A20            600         1       1   49.0      1      0   56.9292
# A23            631         1       1   80.0      0      0   30.0000
# A24            868         0       1   31.0      0      0   50.4958
# A26            648         1       1   56.0      0      0   35.5000
# A31            210         1       1   40.0      0      0   31.0000
# A32            186         0       1    NaN      0      0   50.0000
# A34            446         1       1    4.0      0      2   81.8583
# A36            807         0       1   39.0      0      0    0.0000
# A5              97         0       1   71.0      0      0   34.6542
# ...

# %%
stacked = df1.stack()

# %%
stacked
# Out:
# 0    PassengerId                                                    1
#      Survived                                                       0
#      Pclass                                                         3
#      Name                                     Braund, Mr. Owen Harris
#      Sex                                                         male
#      Age                                                           22
#      SibSp                                                          1
#      Parch                                                          0
#      Ticket                                                 A/5 21171
#      Fare                                                        7.25
#      Embarked                                                       S
# 1    PassengerId                                                    2
#      Survived                                                       1
# ...

# %%
index = pd.MultiIndex.from_df1(df1, names=['first', 'second'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-14198c297a60> in <module>()
# ----> 1 index = pd.MultiIndex.from_df1(df1, names=['first', 'second'])
#
# AttributeError: type object 'MultiIndex' has no attribute 'from_df1'

# %%
df1.plot()

# %%
plt.figure(); df1.plot(); plt.legend(loc='')
# Out:
# C:\Users\Toshiba\Anaconda3\lib\site-packages\matplotlib\legend.py:326: UserWarning: Unrecognized location "". Falling back on "best"; valid locations are
# 	right
# 	center left
# 	upper right
# 	lower right
# 	best
# 	center
# 	lower left
# 	center right
# 	upper left
# 	upper center
# 	lower center
#
#   six.iterkeys(self.codes))))

# %%
plt.matshow(df1.corr())

# %%
corr = df1.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns);
    plt.yticks(range(len(corr.columns)), corr.columns);
# Out:
#   File "<ipython-input-80-14adda85a3dc>", line 2
#     fig, ax = plt.subplots(figsize=(size, size))
#     ^
# IndentationError: unexpected indent

# %%
def plot_corr(df1,size=10)
# Out:
#   File "<ipython-input-81-3d86a1630af9>", line 1
#     def plot_corr(df1,size=10)
#                               ^
# SyntaxError: invalid syntax

# %%
def plot_corr(df1,size=10):
    '''Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''

    corr = df1.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns);
    plt.yticks(range(len(corr.columns)), corr.columns);

# %%
plt.matshow(df1.corr())

# %%
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
mu, sigma = 0.383838 , 0.486592
x = mu + sigma*np.df1.Cabin()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-3ea51d4f2e63> in <module>()
#       1 mu, sigma = 0.383838 , 0.486592
# ----> 2 x = mu + sigma*np.df1.Cabin()
#
# AttributeError: 'module' object has no attribute 'df1'

# %%
# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75)

# %%
# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)

# %%
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'$\mathrm{Histogram\ of\ IQ:}\ \mu=100,\ \sigma=15$')
plt.axis([0, 20, 0, 1.0])
plt.grid(True)

# %%
plt.show()

# %%
tuple = df1

# %%
np.corrcoef('tuple')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-a7ea7e20b05c> in <module>()
# ----> 1 np.corrcoef('tuple')
#
# C:\Users\Toshiba\Anaconda3\lib\site-packages\numpy\lib\function_base.pyc in corrcoef(x, y, rowvar, bias, ddof)
#    2993         warnings.warn('bias and ddof have no effect and are deprecated',
#    2994                       DeprecationWarning, stacklevel=2)
# -> 2995     c = cov(x, y, rowvar)
#    2996     try:
#    2997         d = diag(c)
#
# C:\Users\Toshiba\Anaconda3\lib\site-packages\numpy\lib\function_base.pyc in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2904             w *= aweights
#    2905
# -> 2906     avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2907     w_sum = w_sum[0]
#    2908
#
# C:\Users\Toshiba\Anaconda3\lib\site-packages\numpy\lib\function_base.pyc in average(a, axis, weights, returned)
#    1108
# ...
